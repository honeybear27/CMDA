# %%
#2.

# %%
# !pip install PypeR
# Out:
# ...
# Cleaning up...

# %%
#3.

# %%
import pandas as pd
import pyper as pr
import matplotlib.pyplot as plt

# %%
#4.

# %%
iris = pd.read_csv('iris.csv')

# %%
iris
# Out:
#      sepall  sepalw  petall  petalw  Species
# 0       5.1     3.5     1.4     0.2        0
# 1       4.9     3.0     1.4     0.2        0
# 2       4.7     3.2     1.3     0.2        0
# 3       4.6     3.1     1.5     0.2        0
# 4       5.0     3.6     1.4     0.2        0
# 5       5.4     3.9     1.7     0.4        0
# 6       4.6     3.4     1.4     0.3        0
# 7       5.0     3.4     1.5     0.2        0
# 8       4.4     2.9     1.4     0.2        0
# 9       4.9     3.1     1.5     0.1        0
# 10      5.4     3.7     1.5     0.2        0
# 11      4.8     3.4     1.6     0.2        0
# 12      4.8     3.0     1.4     0.1        0
# 13      4.3     3.0     1.1     0.1        0
# 14      5.8     4.0     1.2     0.2        0
# 15      5.7     4.4     1.5     0.4        0
# 16      5.4     3.9     1.3     0.4        0
# 17      5.1     3.5     1.4     0.3        0
# 18      5.7     3.8     1.7     0.3        0
# 19      5.1     3.8     1.5     0.3        0
# ...

# %%
#5.

# %%
iris.head()
# Out:
#    sepall  sepalw  petall  petalw  Species
# 0     5.1     3.5     1.4     0.2        0
# 1     4.9     3.0     1.4     0.2        0
# 2     4.7     3.2     1.3     0.2        0
# 3     4.6     3.1     1.5     0.2        0
# 4     5.0     3.6     1.4     0.2        0

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.describe
# Out:
# <bound method DataFrame.describe of      sepall  sepalw  petall  petalw  Species
# 0       5.1     3.5     1.4     0.2        0
# 1       4.9     3.0     1.4     0.2        0
# 2       4.7     3.2     1.3     0.2        0
# 3       4.6     3.1     1.5     0.2        0
# 4       5.0     3.6     1.4     0.2        0
# 5       5.4     3.9     1.7     0.4        0
# 6       4.6     3.4     1.4     0.3        0
# 7       5.0     3.4     1.5     0.2        0
# 8       4.4     2.9     1.4     0.2        0
# 9       4.9     3.1     1.5     0.1        0
# 10      5.4     3.7     1.5     0.2        0
# 11      4.8     3.4     1.6     0.2        0
# 12      4.8     3.0     1.4     0.1        0
# 13      4.3     3.0     1.1     0.1        0
# 14      5.8     4.0     1.2     0.2        0
# 15      5.7     4.4     1.5     0.4        0
# 16      5.4     3.9     1.3     0.4        0
# 17      5.1     3.5     1.4     0.3        0
# 18      5.7     3.8     1.7     0.3        0
# ...

# %%
#6.

# %%
r = pr.R(RCMD = 'C:\\Program Files\\R\\R-3.0.1\\bin\\R', use_pandas = True)

# %%
#7.

# %%
r.assign("rdata", iris)

# %%
#8.

# %%
print r("summary(rdata)")
# Out:
# try({summary(rdata)})
#      sepall          sepalw          petall          petalw         Species
#  Min.   :4.300   Min.   :2.000   Min.   :1.000   Min.   :0.100   Min.   :0
#  1st Qu.:5.100   1st Qu.:2.800   1st Qu.:1.600   1st Qu.:0.300   1st Qu.:0
#  Median :5.800   Median :3.000   Median :4.350   Median :1.300   Median :1
#  Mean   :5.843   Mean   :3.054   Mean   :3.759   Mean   :1.199   Mean   :1
#  3rd Qu.:6.400   3rd Qu.:3.300   3rd Qu.:5.100   3rd Qu.:1.800   3rd Qu.:2
#  Max.   :7.900   Max.   :4.400   Max.   :6.900   Max.   :2.500   Max.   :2

# %%
print r("head(iris)")
# Out:
# try({head(iris)})
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1          5.1         3.5          1.4         0.2  setosa
# 2          4.9         3.0          1.4         0.2  setosa
# 3          4.7         3.2          1.3         0.2  setosa
# 4          4.6         3.1          1.5         0.2  setosa
# 5          5.0         3.6          1.4         0.2  setosa
# 6          5.4         3.9          1.7         0.4  setosa

# %%
#9.

# %%
r("?princomp")
# Out:
# 'try({?princomp})\r\nstarting httpd help server ... done\r\n'

# %%
#10.

# %%
r("p<- princomp(rdata[,1:4])")
# Out:
# 'try({p<- princomp(rdata[,1:4])})\r\n'

# %%
#11.

# %%
print r("names(p)")
# Out:
# try({names(p)})
# [1] "sdev"     "loadings" "center"   "scale"    "n.obs"    "scores"   "call"

# %%
#12.

# %%
print r("head(p$scores)")
# Out:
# try({head(p$scores)})
#      Comp.1     Comp.2      Comp.3       Comp.4
# 0 -2.684207  0.3266073 -0.02151184  0.001006157
# 1 -2.715391 -0.1695568 -0.20352143  0.099602424
# 2 -2.889820 -0.1373456  0.02470924  0.019304543
# 3 -2.746437 -0.3111243  0.03767198 -0.075955274
# 4 -2.728593  0.3339246  0.09622970 -0.063128733
# 5 -2.279897  0.7477827  0.17432562 -0.027146804

# %%
#13.

# %%
pydata = pd.DataFrame(r.get("p$scores"))

# %%
#14.

# %%
pydata.head()
# Out:
#           0         1         2         3
# 0 -2.684207  0.326607 -0.021512  0.001006
# 1 -2.715391 -0.169557 -0.203521  0.099602
# 2 -2.889820 -0.137346  0.024709  0.019305
# 3 -2.746437 -0.311124  0.037672 -0.075955
# 4 -2.728593  0.333925  0.096230 -0.063129

# %%
#15.

# %%
plt.scatter(pydata.sepall, pydata.sepalw)
plt.title("Scatterplot")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-4ec2c8f62cbf> in <module>()
# ----> 1 plt.scatter(pydata.sepall, pydata.sepalw)
#       2 plt.title("Scatterplot")
#
# C:\Users\Ronald\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    1841                 return self[name]
#    1842             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1843                                  (type(self).__name__, name))
#    1844
#    1845     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sepall'

# %%
pydata.plot()

# %%
plt.scatter(pydata.A, pydata.B)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-0ff0c32feb29> in <module>()
# ----> 1 plt.scatter(pydata.A, pydata.B)
#
# C:\Users\Ronald\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    1841                 return self[name]
#    1842             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1843                                  (type(self).__name__, name))
#    1844
#    1845     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'A'

# %%
#16.

# %%
from sklearn.decomposition import PCA
estimator = PCA(n_components = 2)
X_pca = estimator.fit_tranform(X_digits)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-548b9ca93624> in <module>()
#       1 from sklearn.decomposition import PCA
#       2 estimator = PCA(n_components = 2)
# ----> 3 X_pca = estimator.fit_tranform(X_digits)
#
# AttributeError: 'PCA' object has no attribute 'fit_tranform'
